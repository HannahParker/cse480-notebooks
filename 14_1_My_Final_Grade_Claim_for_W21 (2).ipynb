# %% [markdown]
# ## Final Grade Claim

# %% [markdown]
# ![Screenshot (271).png](data:image/png;base64,...)

# %% [markdown]
# ## Top Three Evidences

# %% [markdown]
# Readiness Assurance Test 10

# %% [markdown]
# https://colab.research.google.com/github/HannahParker/cse480-notebooks/blob/master/10_1_Readiness_Assurance_Test.ipynb#scrollTo=aNjws7h8mjS7

# %% [markdown]
# Ponder and Prove 9

# %% [markdown]
# https://colab.research.google.com/github/HannahParker/cse480-notebooks/blob/master/09_2_Ponder_and_Prove_Recursively_Enumerable_and_Recursive_Sets.ipynb#scrollTo=98rHo7ggkWwM

# %% [markdown]
# Ponder and Prove 11

# %% [markdown]
# https://colab.research.google.com/github/HannahParker/cse480-notebooks/blob/master/11_2_Ponder_and_Prove_NP_Completeness.ipynb#scrollTo=eA7uftrYb4Ln
